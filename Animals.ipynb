# %% [markdown]
# <a href="https://colab.research.google.com/github/AMRUTHA-KRISHNAN/AMRUTHA-KRISHNAN.github.io/blob/main/Animals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')

# Load datasets
df1 = pd.read_csv('/content/drive/MyDrive/zoo2.csv')
df2 = pd.read_csv('/content/drive/MyDrive/zoo3.csv')

# Combine datasets
df = pd.concat([df1, df2])

# Data Cleaning
df = df.drop_duplicates()
df = df.drop(columns=['animal_name'])

# Split data
X = df.drop('class_type', axis=1)
y = df['class_type']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Import models
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import accuracy_score

models = {
    "Logistic Regression": LogisticRegression(max_iter=200),
    "KNN": KNeighborsClassifier(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Naive Bayes": GaussianNB()
}

# Train & evaluate
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(name, "Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Logistic Regression Accuracy: 0.8260869565217391
# KNN Accuracy: 0.8695652173913043
# Decision Tree Accuracy: 0.8695652173913043
# Random Forest Accuracy: 0.9130434782608695
# Naive Bayes Accuracy: 0.9130434782608695

# %% [markdown]
# # New section
